# %%
import seaborn as sns
# %matplotlib inline

# %%
# Load the dataset
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ## Categorical Plots

# %%
# Barplot
sns.barplot(x='day',y='tip',data=tips)

# %%
# box plot
sns.boxplot(x='day',y='total_bill',data=tips,hue='sex')

# %%
# Violin plot
sns.violinplot(x='day',y='tip',data=tips)

# %%
# strip plot
sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,hue='sex')

# %%
# Factor plot
sns.factorplot(x='day',y='tip',data=tips,kind='point')

# %%
sns.factorplot(x='day',y='tip',data=tips,kind='swarm')

# %% [markdown]
# ## Matrix Plots

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# resetting index of a data frame
tips_grouped_by_day = tips.groupby(by='day',as_index=True)
tips_grouped_by_day.corr()
# Out:
#                      size       tip  total_bill
# day
# Thur size        1.000000  0.646094    0.700123
#      tip         0.646094  1.000000    0.812406
#      total_bill  0.700123  0.812406    1.000000
# Fri  size        1.000000  0.487166    0.630475
#      tip         0.487166  1.000000    0.771934
#      total_bill  0.630475  0.771934    1.000000
# Sat  size        1.000000  0.416737    0.584187
#      tip         0.416737  1.000000    0.703632
#      total_bill  0.584187  0.703632    1.000000
# Sun  size        1.000000  0.450840    0.537981
#      tip         0.450840  1.000000    0.501753
#      total_bill  0.537981  0.501753    1.000000

# %%
sns.heatmap(tips_grouped_by_day.corr(),annot=True)

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
flights_matrix = flights.pivot_table(index='month',columns='year',values='passengers')

# %%
sns.heatmap(flights_matrix,cmap='coolwarm')

# %%
sns.heatmap(flights_matrix,cmap='coolwarm',linecolor='white',lw=0.5)

# %%
# cluster map
sns.clustermap(flights_matrix,cmap='coolwarm',standard_scale=1)

# %% [markdown]
# ## Grids

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.pivot_table(index='species')
# Out:
#             petal_length  petal_width  sepal_length  sepal_width
# species
# setosa             1.462        0.246         5.006        3.428
# versicolor         4.260        1.326         5.936        2.770
# virginica          5.552        2.026         6.588        2.974

# %%
sns.pairplot(iris)

# %%
g = sns.FacetGrid(tips, col='time',row='smoker')
g.map(sns.boxplot, 'total_bill')
# Out:
# /Users/ajay/anaconda3/lib/python3.6/site-packages/seaborn/axisgrid.py:703: UserWarning: Using the boxplot function without specifying `order` is likely to produce an incorrect plot.
#   warnings.warn(warning)

# %%
import matplotlib.pyplot as plt
g = sns.FacetGrid(tips, col='time',row='smoker')
g.map(plt.scatter, 'total_bill','tip')

# %% [markdown]
# ## Regression Plots

# %%
sns.lmplot(x='total_bill',y='tip',data=tips,hue='sex',markers=['+','^'])

# %%
sns.set_style('ticks')
sns.set_context('paper')
sns.lmplot(x='total_bill',y='tip',data=tips,col='day',hue='sex',
          aspect=0.6,size=8)
